# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\bvhvr\OneDrive\Documents\Masai\Masai-Module2\used_cars_messy.csv')

# %%
df.head()
# Out:
#    Unnamed: 0          car_name     brand    model  vehicle_age km_driven  \
# 0        2581    Renault Duster   Renault   Duster            7     67647
# 1         224    Maruti Wagon R    Maruti  Wagon R            3     52000
# 2        1803        Honda City     Honda     City            3     48959
# 3        2728  Mahindra Scorpio  Mahindra  Scorpio            6     82000
# 4       14160   Mahindra XUV500  Mahindra   XUV500            4     34000
#
#   seller_type fuel_type transmission_type mileage  engine  max_power  seats  \
# 0      Dealer    Diesel            Manual   19.87  1461.0      83.80    5.0
# 1      Dealer       CNG            Manual   33.54   998.0      67.04    5.0
# 2      Dealer    Petrol            Manual     NaN  1497.0     117.60    5.0
# 3      dealer    Diesel            Manual    15.4  2179.0        NaN    8.0
# 4      Dealer    Diesel         Automatic    16.0  2179.0     140.00    7.0
#
#    selling_price
# 0       575000.0
# 1       435000.0
# ...

# %%
df['km_driven'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0         67647
# 1         52000
# 2         48959
# 3         82000
# 4         34000
#           ...
# 15656    127731
# 15657     59000
# 15658     20000
# 15659     15000
# 15660     30000
# Name: km_driven, Length: 15661, dtype: str>

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 15661 entries, 0 to 15660
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         15661 non-null  int64
#  1   car_name           15661 non-null  str
#  2   brand              15661 non-null  str
#  3   model              15661 non-null  str
#  4   vehicle_age        15661 non-null  int64
#  5   km_driven          15661 non-null  str
#  6   seller_type        15661 non-null  str
#  7   fuel_type          15661 non-null  str
#  8   transmission_type  15661 non-null  str
#  9   mileage            14376 non-null  str
#  10  engine             13792 non-null  float64
#  11  max_power          14862 non-null  float64
#  12  seats              15218 non-null  float64
#  13  selling_price      15503 non-null  float64
# dtypes: float64(4), int64(2), str(8)
# memory usage: 1.7 MB

# %% [markdown]
#  # FUEL

# %%
# Before Cleaning
df['fuel_type'].unique()
# Out:
# <StringArray>
# [  'Diesel',      'CNG',   'Petrol',  'Petrol ',   'DIESEL',  ' Petrol',
#   'petrol ',   'PETROL',  ' Diesel',  'diesel ',      'LPG',   'petrol',
#    'diesel', 'Electric']
# Length: 14, dtype: str

# %%
df['fuel_type']=df['fuel_type'].astype(str).str.strip().str.title()

# %%
#After Cleaning 
df['fuel_type'].unique()
# Out:
# <StringArray>
# ['Diesel', 'Cng', 'Petrol', 'Lpg', 'Electric']
# Length: 5, dtype: str

# %% [markdown]
# # seller_type

# %%
df['seller_type'].unique()
# Out:
# <StringArray>
# [          'Dealer',           'dealer',       'Individual',
#        'individual',           'DEALER', 'Trustmark Dealer',
#         'Individul',      'Individuall',           'Delaer']
# Length: 9, dtype: str

# %%
df['seller_type']=df['seller_type'].str.strip().str.title()

# %%
df['seller_type'].unique()
# Out:
# <StringArray>
# [          'Dealer',       'Individual', 'Trustmark Dealer',
#         'Individul',      'Individuall',           'Delaer']
# Length: 6, dtype: str

# %%
map={'Delaer':'Dealer',
'Individul':'Individual',
'Individuall':'Individual',
}
df['seller_type']=df['seller_type'].replace(map)

# %%
df['seller_type'].unique()
# Out:
# <StringArray>
# ['Dealer', 'Individual', 'Trustmark Dealer']
# Length: 3, dtype: str

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 15661 entries, 0 to 15660
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         15661 non-null  int64
#  1   car_name           15661 non-null  str
#  2   brand              15661 non-null  str
#  3   model              15661 non-null  str
#  4   vehicle_age        15661 non-null  int64
#  5   km_driven          15661 non-null  str
#  6   seller_type        15661 non-null  str
#  7   fuel_type          15661 non-null  str
#  8   transmission_type  15661 non-null  str
#  9   mileage            14376 non-null  str
#  10  engine             13792 non-null  float64
#  11  max_power          14862 non-null  float64
#  12  seats              15218 non-null  float64
#  13  selling_price      15503 non-null  float64
# dtypes: float64(4), int64(2), str(8)
# memory usage: 1.7 MB

# %%
df['transmission_type'].unique()
# Out:
# <StringArray>
# ['Manual', 'Automatic']
# Length: 2, dtype: str

# %% [markdown]
# # Numerical Cols

# %%
df['vehicle_age'].unique()
# Out:
# array([ 7,  3,  6,  4, 12,  2, 10,  1,  5,  8, 11, 13,  9, 16, 14, 15, 17,
#        18, 29, 25, 21,  0, 19, 22])

# %%
df['km_driven'].unique()
# Out:
# <StringArray>
# [ '67647',  '52000',  '48959',  '82000',  '34000',  '73000',  '88000',
#   '50000',  '30000',  '75220',
#  ...
#   '33350',  '66523', '425785',  '50898',  '17999',  '43001',  '43200',
#   '39337',  '66850', '127731']
# Length: 3868, dtype: str

# %%
df['km_driven'].value_counts()
# Out:
# km_driven
# 50000     554
# 40000     472
# 70000     462
# 60000     448
# 30000     360
#          ...
# 43001       1
# 43200       1
# 39337       1
# 66850       1
# 127731      1
# Name: count, Length: 3868, dtype: int64

# %%
invalid_km_Driven=df[pd.to_numeric(df['km_driven'],errors='coerce').isna()]

# %%
invalid_km_Driven.shape
invalid_km_Driven['km_driven'].unique()
# Out:
# <StringArray>
# [     '7,369',  '42000 kms',   '32000 km',  '62000 kms',  '40000 kms',
#   '43652 kms',     '22,128',   '50000 km',   '54000 km', '100000 kms',
#  ...
#   '16502 kms',      '8,403',   '98000 km',     '14,000',  '70000 kms',
#   '144321 km',     '45,000',  '31497 kms',     '88,466',    '160,000']
# Length: 179, dtype: str

# %%
df['km_driven']=df['km_driven'].astype(str).str.replace('[A-Za-z]',"",regex=True)

# %%
km_Driven=df[pd.to_numeric(df['km_driven'],errors='coerce').isna()]

# %%
invalid_km_Driven=df[pd.to_numeric(df['km_driven'],errors='coerce').isna()]

# %%
invalid_km_Driven.shape
invalid_km_Driven['km_driven'].unique()
# Out:
# <StringArray>
# [  '7,369',  '22,128',  '39,757',  '63,000',  '82,250',  '27,599',  '30,000',
#   '77,000',  '65,000',  '10,000',  '70,000',  '55,001',  '35,000',  '60,000',
#  '110,000',  '12,000',  '37,000',  '80,000', '150,000',  '72,000',  '91,795',
#    '5,381',  '71,000',  '20,000',  '68,387',  '47,347',  '48,000', '155,000',
#   '25,000',  '62,500',  '56,000',   '5,000',   '6,000',  '28,001',  '58,000',
#   '51,000',  '39,000',  '55,000',  '82,000',  '77,433',  '32,241', '100,000',
#    '9,000',  '63,581',  '97,000',  '90,000',  '18,000', '120,000',  '16,631',
#   '83,000',  '40,000',  '75,000',  '13,000', '130,600',  '15,000',   '8,403',
#   '14,000',  '45,000',  '88,466', '160,000']
# Length: 60, dtype: str

# %%
df['km_driven']=df['km_driven'].astype(str).str.replace('[A-Za-z,]',"",regex=True)

# %%
invalid_km_Driven=df[pd.to_numeric(df['km_driven'],errors='coerce').isna()]
invalid_km_Driven.shape
invalid_km_Driven['km_driven'].unique()
# Out:
# <StringArray>
# []
# Length: 0, dtype: str

# %%
df['km_driven']=pd.to_numeric(df['km_driven'],errors='coerce')

# %%
invalid=df[df['mileage'].astype(str).str.contains('[A-Za-z,]',regex=True,na=False)]

# %%
invalid['mileage'].unique()
# Out:
# <StringArray>
# ['33.54 kmpl', '13.68 kmpl', '22.74 kmpl',  '17.4 kmpl', '21.56 kmpl',
#   '24.3 kmpl', '17.01 kmpl',  '18.9 kmpl',  '16.0 kmpl',  '15.4 kmpl',
#  ...
#   '14.0 kmpl',  '11.5 kmpl', '18.69 kmpl', '23.01 kmpl', '25.32 kmpl',
#  '19.59 kmpl', '18.12 kmpl', '28.09 kmpl',  '17.7 kmpl', '24.04 kmpl']
# Length: 109, dtype: str

# %%
df['mileage']=df['mileage'].astype(str).str.replace('[A-Za-z,]',"",regex=True)

# %%
invalid=df[df['mileage'].astype(str).str.contains('[A-Za-z,]',regex=True,na=False)]

# %%
invalid['mileage'].unique()
# Out:
# <StringArray>
# []
# Length: 0, dtype: str

# %%
df['mileage']=pd.to_numeric(df['mileage'],errors='coerce')

# %%
invalid_engine=df[df['engine'].astype(str).str.contains('[A-Za-z,]',regex=True,na=False)]

# %%
invalid_engine['engine'].unique()
# Out:
# array([], dtype=float64)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 15661 entries, 0 to 15660
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         15661 non-null  int64
#  1   car_name           15661 non-null  str
#  2   brand              15661 non-null  str
#  3   model              15661 non-null  str
#  4   vehicle_age        15661 non-null  int64
#  5   km_driven          15661 non-null  int64
#  6   seller_type        15661 non-null  str
#  7   fuel_type          15661 non-null  str
#  8   transmission_type  15661 non-null  str
#  9   mileage            14376 non-null  float64
#  10  engine             13792 non-null  float64
#  11  max_power          14862 non-null  float64
#  12  seats              15218 non-null  float64
#  13  selling_price      15503 non-null  float64
# dtypes: float64(5), int64(3), str(6)
# memory usage: 1.7 MB

# %%
df.describe()
# Out:
#          Unnamed: 0   vehicle_age     km_driven       mileage        engine  \
# count  15661.000000  15661.000000  1.566100e+04  14376.000000  13792.000000
# mean    9808.189643      6.036843  5.562075e+04     19.703828   1480.489342
# std     5642.981540      3.015072  5.152178e+04      4.179440    511.446057
# min        0.000000      0.000000  1.000000e+02      4.000000    793.000000
# 25%     4901.000000      4.000000  3.000000e+04     17.000000   1197.000000
# 50%     9858.000000      6.000000  5.000000e+04     19.670000   1248.000000
# 75%    14666.000000      8.000000  7.000000e+04     22.700000   1582.000000
# max    19543.000000     29.000000  3.800000e+06     33.540000   6592.000000
#
#           max_power         seats  selling_price
# count  14862.000000  15218.000000   1.550300e+04
# mean     100.513582      5.324418   1.032764e+06
# std       42.854632      0.805993   1.607380e+07
# min       38.400000      0.000000   5.000000e+02
# ...

# %%
import numpy as np 
import matplotlib.pyplot as plt 
from sklearn.model_selection import train_test_split,KFold,cross_val_score
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error,r2_score,mean_squared_error

# %%
df=pd.read_csv(r'C:\Users\bvhvr\OneDrive\Documents\Masai\Masai-Module2\IM Session 30 - Regression Regularization\cardekho_dataset (1).csv')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 15411 entries, 0 to 15410
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         15411 non-null  int64
#  1   car_name           15411 non-null  str
#  2   brand              15411 non-null  str
#  3   model              15411 non-null  str
#  4   vehicle_age        15411 non-null  int64
#  5   km_driven          15411 non-null  int64
#  6   seller_type        15411 non-null  str
#  7   fuel_type          15411 non-null  str
#  8   transmission_type  15411 non-null  str
#  9   mileage            15411 non-null  float64
#  10  engine             15411 non-null  int64
#  11  max_power          15411 non-null  float64
#  12  seats              15411 non-null  int64
#  13  selling_price      15411 non-null  int64
# dtypes: float64(2), int64(6), str(6)
# memory usage: 1.6 MB

# %%
df.columns.tolist()
# Out:
# ['Unnamed: 0',
#  'car_name',
#  'brand',
#  'model',
#  'vehicle_age',
#  'km_driven',
#  'seller_type',
#  'fuel_type',
#  'transmission_type',
#  'mileage',
#  'engine',
#  'max_power',
#  'seats',
#  'selling_price']

# %%
df.shape
# Out:
# (15411, 14)

# %%
df.head()
# Out:
#    Unnamed: 0       car_name    brand     model  vehicle_age  km_driven  \
# 0           0    Maruti Alto   Maruti      Alto            9     120000
# 1           1  Hyundai Grand  Hyundai     Grand            5      20000
# 2           2    Hyundai i20  Hyundai       i20           11      60000
# 3           3    Maruti Alto   Maruti      Alto            9      37000
# 4           4  Ford Ecosport     Ford  Ecosport            6      30000
#
#   seller_type fuel_type transmission_type  mileage  engine  max_power  seats  \
# 0  Individual    Petrol            Manual    19.70     796      46.30      5
# 1  Individual    Petrol            Manual    18.90    1197      82.00      5
# 2  Individual    Petrol            Manual    17.00    1197      80.00      5
# 3  Individual    Petrol            Manual    20.92     998      67.10      5
# 4      Dealer    Diesel            Manual    22.77    1498      98.59      5
#
#    selling_price
# 0         120000
# 1         550000
# ...

# %%
df=pd.get_dummies(df,columns=['brand','seller_type','fuel_type','transmission_type'],drop_first=True)

# %%
df.shape
# Out:
# (15411, 48)

# %%
df.head()
# Out:
#    Unnamed: 0       car_name     model  vehicle_age  km_driven  mileage  \
# 0           0    Maruti Alto      Alto            9     120000    19.70
# 1           1  Hyundai Grand     Grand            5      20000    18.90
# 2           2    Hyundai i20       i20           11      60000    17.00
# 3           3    Maruti Alto      Alto            9      37000    20.92
# 4           4  Ford Ecosport  Ecosport            6      30000    22.77
#
#    engine  max_power  seats  selling_price  ...  brand_Toyota  \
# 0     796      46.30      5         120000  ...         False
# 1    1197      82.00      5         550000  ...         False
# 2    1197      80.00      5         215000  ...         False
# 3     998      67.10      5         226000  ...         False
# 4    1498      98.59      5         570000  ...         False
#
#    brand_Volkswagen  brand_Volvo  seller_type_Individual  \
# 0             False        False                    True
# ...

# %%
df.drop

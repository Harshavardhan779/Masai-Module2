# %% [markdown]
# <a href="https://colab.research.google.com/github/Harshavardhan779/Masai-Module2/blob/main/Used_Cars_price_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
